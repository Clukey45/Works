# %% [markdown]
# **Exploration and Analysis of US Chronic Health Indictators** <br>
# Christopher Luke <br>
# 2025
#
# Background: This project focuses on converting publicly available CDC data on chronic disease indicators into a **SQLite** database, enabling efficient querying and analysis of US health trends. The workflow demonstrates data handling in the form of:
#
# - **Extraction**: converting Excel CSV file into a structured SQL database
#
# - **Querying**: leveraging SQL to understand the underlying structure of the dataset and isolate distinct health related topics and questions
#
# - **Processing and visualization**: using Python and SQL for real time visualization and data transformations
#
# - **Analysis**: Using SQL to filter data table and rank top subgroups for health topics (e.g., Alcohol, Obesity in Adults, Cardiovascular Disease)
#
# The analysis highlights the most affected subpopulations across years for selected health topics and associated questions, demonstrating the utility of SQL and Python within an investigative workflow.
#
# Libraries Used: <ins>*sqlite3*</ins> - Lightweight, self-contained SQL database engine integrated with Python for storing and querying structured data <br>
# <ins>*pandas*</ins> - Open source data analysis tool - useful for organizing data into dataframes
# <br>
# <ins>*matplotlib*</ins> - Open source visualization tool - useful for creating bar graphs
#
# Data Source: https://data.cdc.gov/Chronic-Disease-Indicators/U-S-Chronic-Disease-Indicators/hksd-2xuw/about_data

# %%
import sqlite3 as sql 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# To begin, I convert the CSV file into a pandas DataFrame so that I can write it into a SQL database as a table; I create a database named cdi using the sqlite3 module and establish a cursor object to execute SQL queries. Finally, I use two basic queries to display the first five rows of the table as well as using the count() function to verify the size of the table and that the data was loaded correctly.

# %%
file = r'C:\Users\chris\OneDrive\Desktop\USCDI.csv'
df = pd.read_csv(file, low_memory=False)
conn = sql.connect("cdi.db")
cursor = conn.cursor()
df.to_sql("cdi", conn, if_exists="replace", index=False)
conn.commit()
testdf = pd.read_sql_query("SELECT * FROM cdi Limit 5", conn)
pd.set_option('display.max_columns', None)
display(testdf)
# Out:
#    YearStart  YearEnd LocationAbbr   LocationDesc     DataSource  \
# 0       2020     2020           US  United States          BRFSS
# 1       2015     2019           AR       Arkansas  US Cancer DVT
# 2       2015     2019           CA     California  US Cancer DVT
# 3       2015     2019           CO       Colorado  US Cancer DVT
# 4       2015     2019           GA        Georgia  US Cancer DVT
#
#            Topic                                           Question Response  \
# 0  Health Status            Recent activity limitation among adults     None
# 1         Cancer    Invasive cancer (all sites combined), incidence     None
# 2         Cancer  Cervical cancer mortality among all females, u...     None
# 3         Cancer    Invasive cancer (all sites combined), incidence     None
# 4         Cancer  Prostate cancer mortality among all males, und...     None
#
#   DataValueUnit      DataValueType DataValue DataValueAlt  \
# 0        Number  Age-adjusted Mean       2.9          2.9
# 1        Number             Number     9,537        9,537
# 2        Number             Number       486          486
# 3        Number             Number     2,880        2,880
# 4        Number             Number       519          519
#
#   DataValueFootnoteSymbol DataValueFootnote LowConfidenceLimit  \
# 0                    None              None                2.8
# 1                    None              None               None
# 2                    None              None               None
# 3                    None              None               None
# 4                    None              None               None
#
#   HighConfidenceLimit StratificationCategory1      Stratification1  \
# 0                 2.9                     Sex               Female
# 1                None                     Sex                 Male
# 2                None                 Overall              Overall
# 3                None          Race/Ethnicity             Hispanic
# 4                None          Race/Ethnicity  White, non-Hispanic
#
#   StratificationCategory2 Stratification2 StratificationCategory3  \
# 0                    None            None                    None
# 1                    None            None                    None
# 2                    None            None                    None
# 3                    None            None                    None
# 4                    None            None                    None
#
#   Stratification3                                     Geolocation  LocationID  \
# 0            None                                            None          59
# 1            None    POINT (-92.27449074299966 34.74865012400045)           5
# 2            None   POINT (-120.99999953799971 37.63864012300047)           6
# 3            None  POINT (-106.13361092099967 38.843840757000464)           8
# 4            None    POINT (-83.62758034599966 32.83968109300048)          13
#
#   TopicID QuestionID ResponseID DataValueTypeID StratificationCategoryID1  \
# 0     HEA      HEA04       None      AGEADJMEAN                       SEX
# 1     CAN      CAN07       None            NMBR                       SEX
# 2     CAN      CAN03       None            NMBR                   OVERALL
# 3     CAN      CAN07       None            NMBR                      RACE
# 4     CAN      CAN05       None            NMBR                      RACE
#
#   StratificationID1 StratificationCategoryID2 StratificationID2  \
# 0              SEXF                      None              None
# 1              SEXM                      None              None
# 2               OVR                      None              None
# 3               HIS                      None              None
# 4               WHT                      None              None
#
#   StratificationCategoryID3 StratificationID3
# 0                      None              None
# 1                      None              None
# 2                      None              None
# 3                      None              None
# 4                      None              None

# %%
sizecheck = """SELECT COUNT(*) FROM cdi"""
cursor.execute(sizecheck)
display(cursor.fetchall())
colnames = testdf.columns.to_list()
display(colnames, len(colnames))
# Out:
# [(309215,)]
# ['YearStart',
#  'YearEnd',
#  'LocationAbbr',
#  'LocationDesc',
#  'DataSource',
#  'Topic',
#  'Question',
#  'Response',
#  'DataValueUnit',
#  'DataValueType',
#  'DataValue',
#  'DataValueAlt',
#  'DataValueFootnoteSymbol',
#  'DataValueFootnote',
#  'LowConfidenceLimit',
#  'HighConfidenceLimit',
#  'StratificationCategory1',
#  'Stratification1',
#  'StratificationCategory2',
#  'Stratification2',
#  'StratificationCategory3',
#  'Stratification3',
#  'Geolocation',
#  'LocationID',
#  'TopicID',
#  'QuestionID',
#  'ResponseID',
#  'DataValueTypeID',
#  'StratificationCategoryID1',
#  'StratificationID1',
#  'StratificationCategoryID2',
#  'StratificationID2',
#  'StratificationCategoryID3',
#  'StratificationID3']
# 34

# %% [markdown]
# The table consists of nearly 300k rows and 34 columns worth of information.

# %% [markdown]
# Understandably, this is an enormous amount of information and there are many approaches one may take to try and make sense of it all - my approach towards understanding the table will prioritize simplifying the information by removing duplicates and isolating distinct values found within each column - hopefully identifying trends and patterns in the dataset.

# %%
distinct_values_dict = dict()
for col in colnames:
    query = f"SELECT DISTINCT {col} FROM cdi"
    cursor.execute(query)
    rows = cursor.fetchall()
    distinct_values_dict[col] = [row[0] for row in rows]
print(distinct_values_dict)
# Out:
# {'YearStart': [2020, 2015, 2016, 2018, 2019, 2021, 2022], 'YearEnd': [2020, 2019, 2021, 2022], 'LocationAbbr': ['US', 'AR', 'CA', 'CO', 'GA', 'KS', 'ME', 'NJ', 'NY', 'OR', 'SD', 'TX', 'VT', 'WV', 'WI', 'ID', 'WY', 'AZ', 'DC', 'FL', 'HI', 'IL', 'IA', 'MA', 'MN', 'MS', 'NE', 'NH', 'NM', 'NC', 'SC', 'UT', 'AL', 'KY', 'MD', 'MO', 'MT', 'NV', 'ND', 'VI', 'AK', 'CT', 'DE', 'GU', 'IN', 'LA', 'MI', 'OH', 'OK', 'PA', 'PR', 'RI', 'TN', 'VA', 'WA'], 'LocationDesc': ['United States', 'Arkansas', 'California', 'Colorado', 'Georgia', 'Kansas', 'Maine', 'New Jersey', 'New York', 'Oregon', 'South Dakota', 'Texas', 'Vermont', 'West Virginia', 'Wisconsin', 'Idaho', 'Wyoming', 'Arizona', 'District of Columbia', 'Florida', 'Hawaii', 'Illinois', 'Iowa', 'Massachusetts', 'Minnesota', 'Mississippi', 'Nebraska', 'New Hampshire', 'New Mexico', 'North Carolina', 'South Carolina', 'Utah', 'Alabama', 'Kentucky', 'Maryland', 'Missouri', 'Montana', 'Nevada', 'North Dakota', 'Virgin Islands', 'Alaska', 'Connecticut', 'Delaware', 'Guam', 'Indiana', 'Louisiana', 'Michigan', 'Ohio', 'Oklahoma', 'Pennsylvania', 'Puerto Rico', 'Rhode Island', 'Tennessee', 'Virginia', 'Washington'], 'DataSource': ['BRFSS', 'US Cancer DVT', 'NVSS', 'NSCH', 'YRBSS', 'PRAMS', 'Current Population Survey - FSS', 'USRDS', 'ACS', 'CMS Part A Claims Data', 'AEDS', 'NIS', 'ANRF', 'WIC Participant and Program Characteristics'], 'Topic': ['Health Status', 'Cancer', 'Diabetes', 'Sleep', 'Immunization', 'Nutrition, Physical Activity, and Weight Status', 'Oral Health', 'Arthritis', 'Asthma', 'Cardiovascular Disease', 'Disability', 'Mental Health', 'Tobacco', 'Alcohol', 'Chronic Obstructive Pulmonary Disease', 'Social Determinants of Health', 'Cognitive Health and Caregiving', 'Chronic Kidney Disease', 'Maternal Health'], 'Question': ['Recent activity limitation among adults', 'Invasive cancer (all sites combined), incidence', 'Cervical cancer mortality among all females, underlying cause', 'Prostate cancer mortality among all males, underlying cause', 'Breast cancer mortality among all females, underlying cause', 'Invasive cancer (all sites combined) mortality among all people, underlying cause', 'Diabetic ketoacidosis mortality among all people, underlying or contributing cause', 'Lung and bronchial cancer mortality among all people, underlying cause', 'Colon and rectum (colorectal) cancer mortality among all people, underlying cause', 'Short sleep duration among children aged 4 months to 14 years', 'Influenza vaccination among adults', 'Children and adolescents aged 6-13 years meeting aerobic physical activity guideline', 'Receipt of evidence-based preventive dental services in the past 12 months among children and adolescents aged 1-17 years', 'Arthritis among adults', 'Current asthma among adults', 'Taking medicine to control high blood pressure among adults with high blood pressure', 'Coronary heart disease mortality among all people, underlying cause', 'Adults with any disability', 'Frequent mental distress among adults', 'Short sleep duration among high school students', 'Quit attempts in the past year among adult current smokers', 'Binge drinking prevalence among adults', 'Chronic obstructive pulmonary disease mortality among adults aged 45 years and older, underlying cause', 'Frequent physical distress among adults', 'Obesity among adults', 'Received health care provider counseling for physical activity among adults with arthritis', 'Asthma mortality among all people, underlying cause', 'Current smoking among adults with chronic obstructive pulmonary disease', 'Binge drinking frequency among adults who binge drink', 'Depression among adults', 'Physical inactivity among adults with arthritis', 'High cholesterol among adults who have been screened', 'Taking medicine for high cholesterol among adults', 'Cerebrovascular disease (stroke) mortality among all people, underlying cause', 'Influenza vaccination among adults 18â€“64 who are at increased risk', 'Pneumococcal vaccination among adu ...

# %%
print(sum(len(v) for v in distinct_values_dict.values()))
# Out:
# 47606

# %% [markdown]
# While the dictionary of distinct values is much smaller than the parent table, it still contains too many values to immediately find what is important, at least at a surface glance. Instead, I will narrow my investigation to columns pertaining to health topics and their associated questions; I'm choosing this approach because I know my dataset is concerned with chronic disease indictators, and so logically the columns associated with this sort of information may be the backbone structure that other information revolves around.
#
# To visualize the structure, I use an approach which utilizes two sql queries, the first to select distinct values from the topic column and place them in a list, and the second contained within a for loop which iterates through the values in that list and selects distinct questions from rows filtered for that distinct topic, with the final combination being stored in a python dictionary.

# %%
distinct_health_topic = "SELECT DISTINCT Topic FROM cdi"
cursor.execute(distinct_health_topic)
distinct_health_topic = [item[0] for item in cursor.fetchall()]
display(distinct_health_topic)
# Out:
# ['Health Status',
#  'Cancer',
#  'Diabetes',
#  'Sleep',
#  'Immunization',
#  'Nutrition, Physical Activity, and Weight Status',
#  'Oral Health',
#  'Arthritis',
#  'Asthma',
#  'Cardiovascular Disease',
#  'Disability',
#  'Mental Health',
#  'Tobacco',
#  'Alcohol',
#  'Chronic Obstructive Pulmonary Disease',
#  'Social Determinants of Health',
#  'Cognitive Health and Caregiving',
#  'Chronic Kidney Disease',
#  'Maternal Health']

# %%
topic_questions = dict()
for health_topic in distinct_health_topic:
    query = """
    SELECT DISTINCT Question FROM cdi WHERE Topic = ?
    """
    cursor.execute(query, (health_topic,))
    topic = cursor.fetchall()
    topic_questions[health_topic] = [item[0] for item in topic]

display(topic_questions)
# Out:
# {'Health Status': ['Recent activity limitation among adults',
#   'Frequent physical distress among adults',
#   'Life expectancy at birth',
#   'Fair or poor self-rated health status among adults',
#   'Average recent physically unhealthy days among adults',
#   '2 or more chronic conditions among adults'],
#  'Cancer': ['Invasive cancer (all sites combined), incidence',
#   'Cervical cancer mortality among all females, underlying cause',
#   'Prostate cancer mortality among all males, underlying cause',
#   'Breast cancer mortality among all females, underlying cause',
#   'Invasive cancer (all sites combined) mortality among all people, underlying cause',
#   'Lung and bronchial cancer mortality among all people, underlying cause',
#   'Colon and rectum (colorectal) cancer mortality among all people, underlying cause',
#   'Mammography use among women aged 50-74 years',
#   'Cervical cancer screening among women aged 21-65 years',
#   'Colorectal cancer screening among adults aged 45-75 years'],
#  'Diabetes': ['Diabetic ketoacidosis mortality among all people, underlying or contributing cause',
#   'Diabetes among adults',
#   'Gestational diabetes among women with a recent live birth',
#   'Diabetes mortality among all people, underlying or contributing cause'],
#  'Sleep': ['Short sleep duration among children aged 4 months to 14 years',
#   'Short sleep duration among high school students',
#   'Short sleep duration among adults'],
#  'Immunization': ['Influenza vaccination among adults',
#   'Influenza vaccination among adults 18â€“64 who are at increased risk',
#   'Pneumococcal vaccination among adults aged 65 years and older',
#   'Pneumococcal vaccination among adults aged 18â€“64 years who are at increased risk'],
#  'Nutrition, Physical Activity, and Weight Status': ['Children and adolescents aged 6-13 years meeting aerobic physical activity guideline',
#   'Obesity among adults',
#   'No leisure-time physical activity among adults',
#   'Consumed vegetables less than one time daily among adults',
#   'Met aerobic physical activity guideline among high school students',
#   'Consumed fruit less than one time daily among adults',
#   'Consumed vegetables less than one time daily among high school students',
#   'Obesity among high school students',
#   'Consumed regular soda at least one time daily among high school students',
#   'Met aerobic physical activity guideline for substantial health benefits, adults',
#   'Consumed fruit less than one time daily among high school students',
#   'Infants who were breastfed at 12 months',
#   'Infants who were exclusively breastfed through 6 months',
#   'Obesity among WIC children aged 2 to 4 years'],
#  'Oral Health': ['Receipt of evidence-based preventive dental services in the past 12 months among children and adolescents aged 1-17 years',
#   'All teeth lost among adults aged 65 years and older',
#   'Visited dentist or dental clinic in the past year among adults',
#   'No teeth lost among adults aged 18-64 years',
#   'Six or more teeth lost among adults aged 65 years and older',
#   'Visited dentist or other oral health care provider in the past 12 months among children and adolescents aged 1-17 years',
#   'Preventive dental care in the 12 months before pregnancy among women with a recent live birth'],
#  'Arthritis': ['Arthritis among adults',
#   'Received health care provider counseling for physical activity among adults with arthritis',
#   'Physical inactivity among adults with arthritis',
#   'Severe joint pain among adults with arthritis',
#   'Activity limitation due to arthritis among adults with arthritis',
#   'Work limitation due to arthritis among adults aged 18-64 years with arthritis',
#   'Have taken an educational class to learn how to manage arthritis symptoms among adults with arthritis'],
#  'Asthma': ['Current asthma among adults',
#   'Asthma mortality among all people, underlying cause'],
#  'Cardiovascular Disease': ['Taking medicine to control high blood pressure among adults with high blood pressure',
#   'Coronary heart disease mortality among all people, underlying cause',
#   'High cholesterol among adults who have been screened',
#   'Taking medicine for high cholesterol among adults',
#   'Cerebrovascular disease (stroke) mortality among all people, underlying cause',
#   'High blood pressure among adults',
#   'Diseases of the heart mortality among all people, underlying cause',
#   'Hospitalization for heart failure as principal diagnosis, Medicare-beneficiaries aged 65 years and older'],
#  'Disability': ['Adults with any disability'],
#  'Mental Health': ['Frequent mental distress among adults',
#   'Depression among adults',
#   'Average mentally unhealthy days among adults',
#   'Current poor mental health among high school students',
#   'Postpartum depressive symptoms among women with a recent live birth'],
#  'Tobacco': ['Quit attempts in the past year among adult current smokers',
#   'Current cigarette smoking among adults',
#   'Current smokeless tobacco use among high school students',
#   'Cigarette smoking during pregnancy among women with a recent live birth',
#   'Current tobacco use of any tobacco product among high school students',
#   'Current electronic vapor product use among high school students',
#   'Proportion of the population protected by a comprehensive smoke-free policy prohibiting smoking in all indoor areas of workplaces and public places, including restaurants and bars'],
#  'Alcohol': ['Binge drinking prevalence among adults',
#   'Binge drinking frequency among adults who binge drink',
#   'Alcohol use among high school students',
#   'Binge drinking intensity among adults who binge drink',
#   'Binge drinking prevalence among high school students',
#   'Chronic liver disease mortality among all people, underlying cause',
#   'Per capita alcohol consumption among people aged 14 years and older'],
#  'Chronic Obstructive Pulmonary Disease': ['Chronic obstructive pulmonary disease mortality among adults aged 45 years and older, underlying cause',
#   'Current smoking among adults with chronic obstructive pulmonary disease',
#   'Chronic obstructive pulmonary disease among adults',
#   'Chronic obstructive pulmonary disease mortality among adults aged 45 years and older, underlying or contributing cause',
#   'Hospitalization for chronic obstructive pulmonary disease as any diagnosis, Medicare-beneficiaries aged 65 years and older',
#   'Hospitalization for chronic obstructive pulmonary disease as principal diagnosis, Medicare-beneficiaries aged 65 years and older'],
#  'Social Determinants of Health': ['Lack of health insurance among adults aged 18-64 years',
#   'Food insecure in the past 12 months among households',
#   'Routine checkup within the past year among adults',
#   'High school completion among adults aged 18-24',
#   'Unemployment rate among people 16 years and older in the labor force',
#   'Living below 150% of the poverty threshold among all people',
#   'No broadband internet subscription among households',
#   'Unable to pay mortgage, rent, or utility bills in the past 12 months among adults',
#   'Lack of social and emotional support needed among adults',
#   'Lack of reliable transportation in the past 12 months among adults',
#   'Health insurance coverage in the month before pregnancy among women with a recent live birth',
#   'Health insurance coverage after pregnancy among women with a recent live birth'],
#  'Cognitive Health and Caregiving': ['Provided care for someone with dementia or other cognitive impairment in the past month among adults',
#   'Subjective cognitive decline among adults aged 45 years and older',
#   'Provided care for a friend or family member in the past month among adults',
#   'Discussed symptoms of subjective cognitive decline with a health care professional among adults aged 45 years and older with subjective cognitive decline'],
#  'Chronic Kidney Disease': ['Incidence of treated end-stage kidney disease'],
#  'Maternal Health': ['Postpartum checkup among women with a recent live birth']}

# %% [markdown]
# This simplified approach already makes the information easier to comprehend. It appears that health topics (eg., Health Status, Diabetes, Oral Health) may have questions associated with it that help to stratify the population into subgroups based on factors such as age, gender, behavior, and unique life circumstances for that respective topic (eg., Topic - Mental Health, Question - Depression among adults). This structure gives me a method for performing some targeted statistical analysis — by filtering the dataset according to a specific health topic and associated question, I can identify subgroup related patterns for that topic and question and generate insights that would otherwise remain hidden in the overall data. But what topics and questions should I focus on? As valuable as it would be to perform an extensive analysis on every health topic and question combination, that effort would be better suited for a larger scale project. For the sake of focus and feasibility, I will instead select three topic/question combinations using a randomized approach, ensuring that my analysis remains unbiased.

# %%
import random
randomd = dict()
for i in range(3):
    rtopic = (random.choice(list(topic_questions.keys())))
    rquestion = random.choice(list(topic_questions[rtopic]))
    randomd[rtopic] = rquestion
display(randomd)
# Out:
# {'Immunization': 'Influenza vaccination among adults 18â€“64 who are at increased risk',
#  'Alcohol': 'Binge drinking intensity among adults who binge drink',
#  'Social Determinants of Health': 'Lack of reliable transportation in the past 12 months among adults'}

# %% [markdown]
# Disclaimer: The code above will generate a new set of topic/question combinations each instance - it is included for demonstration purposes. For the sake of continuity and reproducibility I have generated a static dictionary below containing the health topic/question combinations created the first instance the code was run.

# %%
tq_for_analysis = {
    ('Disability',):('Adults with any disability',),
    ('Nutrition, Physical Activity, and Weight Status',): ('Obesity among adults',),
    ('Alcohol',): ('Binge drinking frequency among adults who binge drink',) 
}
display(tq_for_analysis)
# Out:
# {('Disability',): ('Adults with any disability',),
#  ('Nutrition, Physical Activity, and Weight Status',): ('Obesity among adults',),
#  ('Alcohol',): ('Binge drinking frequency among adults who binge drink',)}

# %% [markdown]
# While I have narrowed in on an investigative strategy, analyzing additional dimensions with respect to these topics and questions may provide further valuable insights. I plan to examine distinct values across temporal (YearStart, YearEnd), spatial (LocationDesc), measurement (DataValueUnit, DataValueType), and stratification (StratificationCategoryID1, StratificationID1) attributes. Using a similar approach as before, I will iterate through these attributes, retrieve their distinct values via SQL queries, and store all combinations in a structured dictionary for subsequent analysis.

# %%
analysis_cols = ['YearStart','YearEnd','LocationDesc', 'DataValueUnit', 'DataValueType', 'StratificationCategoryID1', 'StratificationID1']
overalld = dict()
for k,v in tq_for_analysis.items():
    k = k[0]
    v = v[0]
    overalld[k] = dict()
    overalld[k]["Question"] = v
    for col in analysis_cols:
        distinct_query = f" SELECT DISTINCT {col} FROM cdi WHERE Topic = ? AND Question = ?"
        cursor.execute(distinct_query, (k,v))
        overalld[k][col] = [item[0] for item in cursor.fetchall()]
display(overalld)
# Out:
# {'Disability': {'Question': 'Adults with any disability',
#   'YearStart': [2019, 2020, 2021, 2022],
#   'YearEnd': [2019, 2020, 2021, 2022],
#   'LocationDesc': ['Alabama',
#    'Alaska',
#    'Georgia',
#    'Iowa',
#    'Kentucky',
#    'Maine',
#    'Montana',
#    'Nebraska',
#    'New York',
#    'Rhode Island',
#    'Texas',
#    'Delaware',
#    'Michigan',
#    'Minnesota',
#    'New Mexico',
#    'Pennsylvania',
#    'Virgin Islands',
#    'Connecticut',
#    'Ohio',
#    'Maryland',
#    'Mississippi',
#    'United States',
#    'Vermont',
#    'West Virginia',
#    'Wisconsin',
#    'Colorado',
#    'District of Columbia',
#    'Florida',
#    'Missouri',
#    'North Dakota',
#    'Puerto Rico',
#    'Tennessee',
#    'Virginia',
#    'Oklahoma',
#    'Arizona',
#    'Arkansas',
#    'California',
#    'Guam',
#    'Hawaii',
#    'Idaho',
#    'Indiana',
#    'Kansas',
#    'Illinois',
#    'Louisiana',
#    'New Hampshire',
#    'Massachusetts',
#    'Nevada',
#    'New Jersey',
#    'North Carolina',
#    'South Carolina',
#    'South Dakota',
#    'Oregon',
#    'Washington',
#    'Utah',
#    'Wyoming'],
#   'DataValueUnit': ['%'],
#   'DataValueType': ['Crude Prevalence', 'Age-adjusted Prevalence'],
#   'StratificationCategoryID1': ['RACE', 'SEX', 'OVERALL', 'AGE'],
#   'StratificationID1': ['WHT',
#    'SEXF',
#    'OVR',
#    'AGE1844',
#    'AIAN',
#    'SEXM',
#    'AGE65P',
#    'HIS',
#    'AGE4564',
#    'MRC',
#    'BLK',
#    'HAPI',
#    'ASN']},
#  'Nutrition, Physical Activity, and Weight Status': {'Question': 'Obesity among adults',
#   'YearStart': [2019, 2021, 2020, 2022],
#   'YearEnd': [2019, 2021, 2020, 2022],
#   'LocationDesc': ['Alaska',
#    'Pennsylvania',
#    'Rhode Island',
#    'United States',
#    'Vermont',
#    'Montana',
#    'Nebraska',
#    'North Carolina',
#    'Virgin Islands',
#    'West Virginia',
#    'California',
#    'Connecticut',
#    'Hawaii',
#    'North Dakota',
#    'Utah',
#    'Wyoming',
#    'Arizona',
#    'Arkansas',
#    'Alabama',
#    'Nevada',
#    'Delaware',
#    'Georgia',
#    'District of Columbia',
#    'Guam',
#    'Florida',
#    'Colorado',
#    'Louisiana',
#    'Kentucky',
#    'Maine',
#    'Idaho',
#    'Indiana',
#    'Iowa',
#    'Illinois',
#    'New Mexico',
#    'Kansas',
#    'Michigan',
#    'Missouri',
#    'Maryland',
#    'Massachusetts',
#    'Mississippi',
#    'Minnesota',
#    'Oklahoma',
#    'New Jersey',
#    'New York',
#    'Ohio',
#    'New Hampshire',
#    'South Carolina',
#    'South Dakota',
#    'Puerto Rico',
#    'Tennessee',
#    'Texas',
#    'Oregon',
#    'Washington',
#    'Virginia',
#    'Wisconsin'],
#   'DataValueUnit': ['%'],
#   'DataValueType': ['Crude Prevalence', 'Age-adjusted Prevalence'],
#   'StratificationCategoryID1': ['AGE', 'RACE', 'SEX', 'OVERALL'],
#   'StratificationID1': ['AGE1844',
#    'HIS',
#    'SEXF',
#    'OVR',
#    'SEXM',
#    'AGE65P',
#    'AIAN',
#    'WHT',
#    'MRC',
#    'HAPI',
#    'BLK',
#    'AGE4564',
#    'ASN']},
#  'Alcohol': {'Question': 'Binge drinking frequency among adults who binge drink',
#   'YearStart': [2020, 2019, 2021, 2022],
#   'YearEnd': [2020, 2019, 2021, 2022],
#   'LocationDesc': ['West Virginia',
#    'Maryland',
#    'Nevada',
#    'Puerto Rico',
#    'Texas',
#    'Vermont',
#    'Indiana',
#    'Missouri',
#    'Rhode Island',
#    'Florida',
#    'Nebraska',
#    'South Dakota',
#    'Colorado',
#    'Illinois',
#    'Kentucky',
#    'Michigan',
#    'Pennsylvania',
#    'Wisconsin',
#    'Arizona',
#    'Alabama',
#    'California',
#    'Alaska',
#    'Arkansas',
#    'North Dakota',
#    'District of Columbia',
#    'Guam',
#    'Delaware',
#    'Connecticut',
#    'Idaho',
#    'Georgia',
#    'Hawaii',
#    'Iowa',
#    'Kansas',
#    'Louisiana',
#    'Maine',
#    'New Mexico',
#    'Montana',
#    'Massachusetts',
#    'Mississippi',
#    'Minnesota',
#    'Oregon',
#    'New Jersey',
#    'Oklahoma',
#    'Ohio',
#    'North Carolina',
#    'New York',
#    'New Hampshire',
#    'South Carolina',
#    'Tennessee',
#    'United States',
#    'Virginia',
#    'Virgin Islands',
#    'Wyoming',
#    'Washington',
#    'Utah'],
#   'DataValueUnit': ['Number'],
#   'DataValueType': ['Crude Median', 'Crude 75th percentile'],
#   'StratificationCategoryID1': ['RACE', 'AGE', 'SEX', 'OVERALL'],
#   'StratificationID1': ['HIS',
#    'AGE65P',
#    'AGE1844',
#    'SEXF',
#    'WHT',
#    'SEXM',
#    'OVR',
#    'MRC',
#    'BLK',
#    'AGE4564',
#    'AIAN',
#    'HAPI',
#    'ASN']}}

# %% [markdown]
# Now we have both the big picture and a finer resolution. The dictionary reveals key patterns in the dataset: for these topic–question combinations, locations cover all U.S. states and territories, and information is provided over multiple years (2019–2022), enabling recent multi-year comparisons. Data values include metrics such as crude and age-adjusted prevalence or medians, with units reflecting percentages or raw counts. Stratification captures various subgroups, providing detailed breakdowns while also including overall metrics that establish a baseline for meaningful comparisons across populations. This structure allows the analysis to focus on the relative difference between each subgroup and the overall population metric for a given year and location, highlighting the subgroups that deviate most from the state-level average.
#
# To operationalize this comparison, SQL queries were used to first extract the overall values for each state, year, and measurement type. The query leverages common table expressions (CTEs) to organize the overall values and joins them back to the subgroup data, effectively performing a self-join. A window function (RANK) is applied within each combination of year, state, and data type to identify the top 10 subgroups with the largest deviations. This approach ensures the analysis focuses on the most pronounced disparities rather than treating all subgroup values equally. Storing these results in a structured dictionary enables rapid exploration of which subgroups consistently deviate most from the state-level averages, supporting a focused and actionable analysis of population-level differences.

# %%
dfdict = dict()
for k,v in tq_for_analysis.items():
    k = k[0]
    v = v[0]
    param = (k,v,k,v)
    race_vs_overall_stats_per_state = """
    WITH overall AS (
    SELECT * 
    FROM cdi 
    WHERE Topic = ? 
      AND Question = ? 
      AND StratificationCategoryID1 = 'OVERALL'
    ),
    joined AS (
    SELECT 
        cdi.*, 
        overall.DataValue AS StateOverall, 
        cdi.DataValue - overall.DataValue AS Difference,
        RANK() OVER(
            PARTITION BY cdi.YearStart, cdi.YearEnd, cdi.DataValueType
            ORDER BY cdi.DataValue - overall.DataValue DESC
        ) AS Rank
    FROM cdi
    JOIN overall
      ON cdi.YearStart = overall.YearStart 
     AND cdi.YearEnd = overall.YearEnd 
     AND cdi.LocationDesc = overall.LocationDesc 
     AND cdi.DataValueType = overall.DataValueType
    WHERE cdi.Topic = ? 
      AND cdi.Question = ?
    )
    SELECT * 
    FROM joined
    WHERE Rank <= 10
   
    """ 
    dfdict[k,v] = pd.read_sql_query(race_vs_overall_stats_per_state, conn, params = param)
display(dfdict)
# Out:
# {('Disability',
#   'Adults with any disability'):     YearStart  YearEnd LocationAbbr   LocationDesc DataSource       Topic  \
#  0        2019     2019           MO       Missouri      BRFSS  Disability
#  1        2019     2019           ME          Maine      BRFSS  Disability
#  2        2019     2019           IN        Indiana      BRFSS  Disability
#  3        2019     2019           LA      Louisiana      BRFSS  Disability
#  4        2019     2019           MI       Michigan      BRFSS  Disability
#  ..        ...      ...          ...            ...        ...         ...
#  75       2022     2022           GA        Georgia      BRFSS  Disability
#  76       2022     2022           PR    Puerto Rico      BRFSS  Disability
#  77       2022     2022           CA     California      BRFSS  Disability
#  78       2022     2022           ND   North Dakota      BRFSS  Disability
#  79       2022     2022           NH  New Hampshire      BRFSS  Disability
#
#                        Question Response DataValueUnit  \
#  0   Adults with any disability     None             %
#  1   Adults with any disability     None             %
#  2   Adults with any disability     None             %
#  3   Adults with any disability     None             %
#  4   Adults with any disability     None             %
#  ..                         ...      ...           ...
#  75  Adults with any disability     None             %
#  76  Adults with any disability     None             %
#  77  Adults with any disability     None             %
#  78  Adults with any disability     None             %
#  79  Adults with any disability     None             %
#
#                DataValueType DataValue DataValueAlt DataValueFootnoteSymbol  \
#  0   Age-adjusted Prevalence      65.6         65.6                    None
#  1   Age-adjusted Prevalence      55.6         55.6                    None
#  2   Age-adjusted Prevalence      53.4         53.4                    None
#  3   Age-adjusted Prevalence      59.7         59.7                    None
#  4   Age-adjusted Prevalence      53.2         53.2                    None
#  ..                      ...       ...          ...                     ...
#  75         Crude Prevalence        53           53                    None
#  76         Crude Prevalence      66.8         66.8                    None
#  77         Crude Prevalence        47           47                    None
#  78         Crude Prevalence      45.7         45.7                    None
#  79         Crude Prevalence      46.7         46.7                    None
#
#     DataValueFootnote LowConfidenceLimit HighConfidenceLimit  \
#  0               None               49.8                78.6
#  1               None               38.4                71.5
#  2               None               38.7                67.5
#  3               None               47.4                70.9
#  4               None                 41                65.1
#  ..               ...                ...                 ...
#  75              None               30.3                74.5
#  76              None               63.8                69.8
#  77              None               33.3                61.2
#  78              None               42.8                48.6
#  79              None               30.3                63.7
#
#     StratificationCategory1                                 Stratification1  \
#  0           Race/Ethnicity  American Indian or Alaska Native, non-Hispanic
#  1           Race/Ethnicity  American Indian or Alaska Native, non-Hispanic
#  2           Race/Ethnicity  American Indian or Alaska Native, non-Hispanic
#  3           Race/Ethnicity                       Multiracial, non-Hispanic
#  4           Race/Ethnicity  American Indian or Alaska Native, non-Hispanic
#  ..                     ...                                             ...
#  75          Race/Ethnicity  American Indian or Alaska Native, non-Hispanic
#  76                     Age                                        Age >=65
#  77          Race/Ethnicity  American Indian or Alaska Native, non-Hispanic
#  78                     Age                                        Age >=65
#  79          Race/Ethnicity                       Multiracial, non-Hispanic
#
#     StratificationCategory2 Stratification2 StratificationCategory3  \
#  0                     None            None                    None
#  1                     None            None                    None
#  2                     None            None                    None
#  3                     None            None                    None
#  4                     None            None                    None
#  ..                     ...             ...                     ...
#  75                    None            None                    None
#  76                    None            None                    None
#  77                    None            None                    None
#  78                    None            None                    None
#  79                    None            None                    None
#
#     Stratification3                                    Geolocation  LocationID  \
#  0             None  POINT (-92.56630005299968 38.635790776000476)          29
#  1             None  POINT (-68.98503133599962 45.254228894000505)          23
#  2             None  POINT (-86.14996019399968 39.766910452000445)          18
#  3             None   POINT (-92.44568007099969 31.31266064400046)          22
#  4             None    POINT (-84.71439026999968 44.6613195430005)          26
#  ..             ...                                            ...         ...
#  75            None   POINT (-83.62758034599966 32.83968109300048)          13
#  76            None                   POINT (-66.590149 18.220833)          72
#  77            None  POINT (-120.99999953799971 37.63864012300047)           6
#  78            None  POINT (-100.11842104899966 47.47531977900047)          38
#  79            None   POINT (-71.50036091999965 43.65595011300047)          33
#
#     TopicID QuestionID ResponseID DataValueTypeID StratificationCategoryID1  \
#  0      DIS      DIS01       None      AGEADJPREV                      RACE
#  1      DIS      DIS01       None      AGEADJPREV                      RACE
#  2      DIS      DIS01       None      AGEADJPREV                      RACE
#  3      DIS      DIS01       None      AGEADJPREV                      RACE
#  4      DIS      DIS01       None      AGEADJPREV                      RACE
#  ..     ...        ...        ...             ...                       ...
#  75     DIS      DIS01       None         CRDPREV                      RACE
#  76     DIS      DIS01       None         CRDPREV                       AGE
#  77     DIS      DIS01       None         CRDPREV                      RACE
#  78     DIS      DIS01       None         CRDPREV                       AGE
#  79     DIS      DIS01       None         CRDPREV                      RACE
#
#     StratificationID1 StratificationCategoryID2 StratificationID2  \
#  0               AIAN                      None              None
#  1               AIAN                      None              None
#  2               AIAN                      None              None
#  3                MRC                      None              None
#  4               AIAN                      None              None
#  ..               ...                       ...               ...
#  75              AIAN                      None              None
#  76            AGE65P                      None              None
#  77              AIAN                      None              None
#  78            AGE65P                      None              None
#  79               MRC                      None              None
#
#     StratificationCategoryID3 StratificationID3 StateOverall  Difference  Rank
#  0                       None              None         29.9        35.7     1
#  1                       None              None         29.8        25.8     2
#  2                       None              None         27.7        25.7     3
#  3                       None              None         34.2        25.5     4
#  4                       None              None         28.9        24.3     5
#  ..                       ...               ...          ...         ...   ...
#  75                      None              None         29.7        23.3     6
#  76                      None              None         44.6        22.2     7
#  77                      None              None         27.5        19.5     8
#  78                      None              None         26.9        18.8     9
#  79                      None              None         28.5        18.2    10
#
#  [80 rows x 37 columns],
#  ('Nutrition, Physical Activity, and Weight Status',
#   'Obesity among adults'):     YearStart  YearEnd LocationAbbr          LocationDesc DataSource  \
#  0        2019     2019           AR              Arkansas      BRFSS
#  1        2019     2019           HI                Hawaii      BRFSS
#  2        2019     2019           AZ               Arizona      BRFSS
#  3        2019     2019           ND          North Dakota      BRFSS
#  4        2019     2019           MN             Minnesota      BRFSS
#  ..        ...      ...          ...                   ...        ...
#  76       2022     2022           RI          Rhode Island      BRFSS
#  77       2022     2022           VA              Virginia      BRFSS
#  78       2022     2022           DC  District of Columbia      BRFSS
#  79       2022     2022           AZ               Arizona      BRFSS
#  80       2022     2022           CA            California      BRFSS
#
#                                                Topic              Question  \
#  0   Nutrition, Physical Activity, and Weight Status  Obesity among adults
#  1   Nutrition, Physical Activity, and Weight Status  Obesity among adults
#  2   Nutrition, Physical Activity, and Weight Status  Obesity among adults
#  3   Nutrition, Physical Activity, and Weight Status  Obesity among adults
#  4   Nutrition, Physical Activity, and Weight Status  Obesity among adults
#  ..                                              ...                   ...
#  76  Nutrition, Physical Activity, and Weight Status  Obesity among adults
#  77  Nutrition, Physical Activity, and Weight Status  Obesity among adults
#  78  Nutrition, Physical Activity, and Weight Status  Obesity among adults
#  79  Nutrition, Physical Activity, and Weight Status  Obesity among adults
#  80  Nutrition, Physical Activity, and Weight Status  Obesity among adults
#
#     Response DataValueUnit            DataValueType DataValue DataValueAlt  \
#  0      None             %  Age-adjusted Prevalence        66           66
#  1      None             %  Age-adjusted Prevalence      50.4         50.4
#  2      None             %  Age-adjusted Prevalence      56.5         56.5
#  3      None             %  Age-adjusted Prevalence      58.4         58.4
#  4      None             %  Age-adjusted Prevalence      49.3         49.3
#  ..      ...           ...                      ...       ...          ...
#  76     None             %         Crude Prevalence      45.9         45.9
#  77     None             %         Crude Prevalence      50.2         50.2
#  78     None             %         Crude Prevalence      39.2         39.2
#  79     None             %         Crude Prevalence      47.9         47.9
#  80     None             %         Crude Prevalence      42.4         42.4
#
#     DataValueFootnoteSymbol DataValueFootnote LowConfidenceLimit  \
#  0                     None              None               51.3
#  1                     None              None               46.1
#  2                     None              None               49.2
#  3                     None              None               48.5
#  4                     None              None               40.7
#  ..                     ...               ...                ...
#  76                    None              None               31.1
#  77                    None              None               46.6
#  78                    None              None               35.3
#  79                    None              None               40.1
#  80                    None              None               28.7
#
#     HighConfidenceLimit StratificationCategory1  \
#  0                 78.2          Race/Ethnicity
#  1                 54.7          Race/Ethnicity
#  2                 63.5          Race/Ethnicity
#  3                 67.7          Race/Ethnicity
#  4                 57.9          Race/Ethnicity
#  ..                 ...                     ...
#  76                61.4          Race/Ethnicity
#  77                53.8          Race/Ethnicity
#  78                43.1          Race/Ethnicity
#  79                55.8          Race/Ethnicity
#  80                57.4          Race/Ethnicity
#
#                                     Stratification1 StratificationCategory2  \
#  0   American Indian or Alaska Native, non-Hispanic                    None
#  1       Hawaiian or Pacific Islander, non-Hispanic                    None
#  2   American Indian or Alaska Native, non-Hispanic                    None
#  3   American Indian or Alaska Native, non-Hispanic                    None
#  4   American Indian or Alaska Native, non-Hispanic                    None
#  ..                                             ...                     ...
#  76                       Multiracial, non-Hispanic                    None
#  77                             Black, non-Hispanic                    None
#  78                             Black, non-Hispanic                    None
#  79  American Indian or Alaska Native, non-Hispanic                    None
#  80  American Indian or Alaska Native, non-Hispanic                    None
#
#     Stratification2 StratificationCategory3 Stratification3  \
#  0             None                    None            None
#  1             None                    None            None
#  2             None                    None            None
#  3             None                    None            None
#  4             None                    None            None
#  ..             ...                     ...             ...
#  76            None                    None            None
#  77            None                    None            None
#  78            None                    None            None
#  79            None                    None            None
#  80            None                    None            None
#
#                                         Geolocation  LocationID TopicID  \
#  0     POINT (-92.27449074299966 34.74865012400045)           5    NPAW
#  1   POINT (-157.85774940299973 21.304850435000446)          15    NPAW
#  2   POINT (-111.76381127699972 34.865970280000454)           4    NPAW
#  3    POINT (-100.11842104899966 47.47531977900047)          38    NPAW
#  4     POINT (-94.79420050299967 46.35564873600049)          27    NPAW
#  ..                                             ...         ...     ...
#  76    POINT (-71.52247031399963 41.70828019300046)          44    NPAW
#  77    POINT (-78.45789046299967 37.54268067400045)          51    NPAW
#  78                    POINT (-77.036871 38.907192)          11    NPAW
#  79  POINT (-111.76381127699972 34.865970280000454)           4    NPAW
#  80   POINT (-120.99999953799971 37.63864012300047)           6    NPAW
#
#     QuestionID ResponseID DataValueTypeID StratificationCategoryID1  \
#  0       NPW14       None      AGEADJPREV                      RACE
#  1       NPW14       None      AGEADJPREV                      RACE
#  2       NPW14       None      AGEADJPREV                      RACE
#  3       NPW14       None      AGEADJPREV                      RACE
#  4       NPW14       None      AGEADJPREV                      RACE
#  ..        ...        ...             ...                       ...
#  76      NPW14       None         CRDPREV                      RACE
#  77      NPW14       None         CRDPREV                      RACE
#  78      NPW14       None         CRDPREV                      RACE
#  79      NPW14       None         CRDPREV                      RACE
#  80      NPW14       None         CRDPREV                      RACE
#
#     StratificationID1 StratificationCategoryID2 StratificationID2  \
#  0               AIAN                      None              None
#  1               HAPI                      None              None
#  2               AIAN                      None              None
#  3               AIAN                      None              None
#  4               AIAN                      None              None
#  ..               ...                       ...               ...
#  76               MRC                      None              None
#  77               BLK                      None              None
#  78               BLK                      None              None
#  79              AIAN                      None              None
#  80              AIAN                      None              None
#
#     StratificationCategoryID3 StratificationID3 StateOverall  Difference  Rank
#  0                       None              None           38        28.0     1
#  1                       None              None         25.5        24.9     2
#  2                       None              None         31.9        24.6     3
#  3                       None              None         35.8        22.6     4
#  4                       None              None           30        19.3     5
#  ..                       ...               ...          ...         ...   ...
#  76                      None              None         30.8        15.1     6
#  77                      None              None         35.2        15.0     7
#  78                      None              None         24.3        14.9     8
#  79                      None              None         33.2        14.7     9
#  80                      None              None         28.1        14.3    10
#
#  [81 rows x 37 columns],
#  ('Alcohol',
#   'Binge drinking frequency among adults who binge drink'):     YearStart  YearEnd LocationAbbr    LocationDesc DataSource    Topic  \
#  0        2019     2019           FL         Florida      BRFSS  Alcohol
#  1        2019     2019           MN       Minnesota      BRFSS  Alcohol
#  2        2019     2019           AR        Arkansas      BRFSS  Alcohol
#  3        2019     2019           HI          Hawaii      BRFSS  Alcohol
#  4        2019     2019           GU            Guam      BRFSS  Alcohol
#  ..        ...      ...          ...             ...        ...      ...
#  79       2022     2022           MN       Minnesota      BRFSS  Alcohol
#  80       2022     2022           VI  Virgin Islands      BRFSS  Alcohol
#  81       2022     2022           FL         Florida      BRFSS  Alcohol
#  82       2022     2022           MS     Mississippi      BRFSS  Alcohol
#  83       2022     2022           SC  South Carolina      BRFSS  Alcohol
#
#                                               Question Response DataValueUnit  \
#  0   Binge drinking frequency among adults who bing...     None        Number
#  1   Binge drinking frequency among adults who bing...     None        Number
#  2   Binge drinking frequency among adults who bing...     None        Number
#  3   Binge drinking frequency among adults who bing...     None        Number
#  4   Binge drinking frequency among adults who bing...     None        Number
#  ..                                                ...      ...           ...
#  79  Binge drinking frequency among adults who bing...     None        Number
#  80  Binge drinking frequency among adults who bing...     None        Number
#  81  Binge drinking frequency among adults who bing...     None        Number
#  82  Binge drinking frequency among adults who bing...     None        Number
#  83  Binge drinking frequency among adults who bing...     None        Number
#
#              DataValueType DataValue DataValueAlt DataValueFootnoteSymbol  \
#  0   Crude 75th percentile       7.2          7.2                    None
#  1   Crude 75th percentile       5.9          5.9                    None
#  2   Crude 75th percentile       7.6          7.6                    None
#  3   Crude 75th percentile       6.4          6.4                    None
#  4   Crude 75th percentile       5.7          5.7                    None
#  ..                    ...       ...          ...                     ...
#  79           Crude Median       2.7          2.7                    None
#  80           Crude Median       2.7          2.7                    None
#  81           Crude Median       3.2          3.2                    None
#  82           Crude Median         3            3                    None
#  83           Crude Median       3.1          3.1                    None
#
#     DataValueFootnote LowConfidenceLimit HighConfidenceLimit  \
#  0               None                4.3                11.3
#  1               None                4.1                10.5
#  2               None                  5                 9.4
#  3               None                4.8                   8
#  4               None                  3                 8.5
#  ..               ...                ...                 ...
#  79              None                1.5                   4
#  80              None                  0                 4.4
#  81              None                2.5                 3.8
#  82              None                1.7                 3.7
#  83              None                2.4                   4
#
#     StratificationCategory1            Stratification1 StratificationCategory2  \
#  0           Race/Ethnicity  Multiracial, non-Hispanic                    None
#  1           Race/Ethnicity  Multiracial, non-Hispanic                    None
#  2           Race/Ethnicity        Black, non-Hispanic                    None
#  3                      Sex                       Male                    None
#  4           Race/Ethnicity        White, non-Hispanic                    None
#  ..                     ...                        ...                     ...
#  79          Race/Ethnicity        Black, non-Hispanic                    None
#  80                     Sex                       Male                    None
#  81                     Age                  Age 45-64                    None
#  82                     Age                  Age 45-64                    None
#  83          Race/Ethnicity        Black, non-Hispanic                    None
#
#     Stratification2 StratificationCategory3 Stratification3  \
#  0             None                    None            None
#  1             None                    None            None
#  2             None                    None            None
#  3             None                    None            None
#  4             None                    None            None
#  ..             ...                     ...             ...
#  79            None                    None            None
#  80            None                    None            None
#  81            None                    None            None
#  82            None                    None            None
#  83            None                    None            None
#
#                                         Geolocation  LocationID TopicID  \
#  0    POINT (-81.92896053899966 28.932040377000476)          12     ALC
#  1     POINT (-94.79420050299967 46.35564873600049)          27     ALC
#  2     POINT (-92.27449074299966 34.74865012400045)           5     ALC
#  3   POINT (-157.85774940299973 21.304850435000446)          15     ALC
#  4                     POINT (144.793731 13.444304)          66     ALC
#  ..                                             ...         ...     ...
#  79    POINT (-94.79420050299967 46.35564873600049)          27     ALC
#  80                    POINT (-64.896335 18.335765)          78     ALC
#  81   POINT (-81.92896053899966 28.932040377000476)          12     ALC
#  82   POINT (-89.53803082499968 32.745510099000455)          28     ALC
#  83   POINT (-81.04537120699968 33.998821303000454)          45     ALC
#
#     QuestionID ResponseID DataValueTypeID StratificationCategoryID1  \
#  0       ALC04       None         CRD75TH                      RACE
#  1       ALC04       None         CRD75TH                      RACE
#  2       ALC04       None         CRD75TH                      RACE
#  3       ALC04       None         CRD75TH                       SEX
#  4       ALC04       None         CRD75TH                      RACE
#  ..        ...        ...             ...                       ...
#  79      ALC04       None         CRDMEDN                      RACE
#  80      ALC04       None         CRDMEDN                       SEX
#  81      ALC04       None         CRDMEDN                       AGE
#  82      ALC04       None         CRDMEDN                       AGE
#  83      ALC04       None         CRDMEDN                      RACE
#
#     StratificationID1 StratificationCategoryID2 StratificationID2  \
#  0                MRC                      None              None
#  1                MRC                      None              None
#  2                BLK                      None              None
#  3               SEXM                      None              None
#  4                WHT                      None              None
#  ..               ...                       ...               ...
#  79               BLK                      None              None
#  80              SEXM                      None              None
#  81           AGE4564                      None              None
#  82           AGE4564                      None              None
#  83               BLK                      None              None
#
#     StratificationCategoryID3 StratificationID3 StateOverall  Difference  Rank
#  0                       None              None          4.4         2.8     1
#  1                       None              None          3.8         2.1     2
#  2                       None              None          5.5         2.1     3
#  3                       None              None          4.5         1.9     4
#  4                       None              None            4         1.7     5
#  ..                       ...               ...          ...         ...   ...
#  79                      None              None          1.7         1.0     7
#  80                      None              None          1.7         1.0     7
#  81                      None              None          2.2         1.0     9
#  82                      None              None            2         1.0     9
#  83                      None              None          2.1         1.0     9
#
#  [84 rows x 37 columns]}

# %% [markdown]
# Following the collection of results into the dictionary, vertical bar charts were created to visualize the top 10 relative differences for each topic/question combination. For each subset, the most frequently occurring metric was selected to standardize comparisons across locations and years, and only the latest year of data was used for each graph. Subgroups were then ranked by their difference from the overall population metric, and the top 10 deviations were displayed as vertical bars. Each bar represents a specific subgroup and location, with the height corresponding to the magnitude of deviation from the state-level average.
#
# These visualizations enable rapid identification of which subgroups consistently deviate most from the overall population metric, highlighting potential disparities across states. By combining the dictionary structure with these vertical bar charts, the analysis becomes both data-driven and interpretable, allowing for immediate exploration of patterns without rerunning complex queries. The inclusion of year and metric in the plot titles provides full context for each visualization, making it easy to compare trends across different measurement types.

# %%
chosen_metrics = {}
for (topic, question), df in dfdict.items():
    most_common_metric = df['DataValueType'].mode()[0]
    chosen_metrics[(topic, question)] = most_common_metric
display(chosen_metrics)
# Out:
# {('Disability', 'Adults with any disability'): 'Age-adjusted Prevalence',
#  ('Nutrition, Physical Activity, and Weight Status',
#   'Obesity among adults'): 'Crude Prevalence',
#  ('Alcohol',
#   'Binge drinking frequency among adults who binge drink'): 'Crude 75th percentile'}

# %%
top10 = dict()

for (topic, question), df in dfdict.items():
    latest_year = df['YearEnd'].max()
    metric = chosen_metrics[(topic, question)]
    df_filtered = df[(df['YearEnd'] == latest_year) & (df['DataValueType'] == metric)]
    df_top10 = df_filtered.sort_values('Difference', ascending=False).head(10).copy()
    df_top10['Label'] = (df_top10['Stratification1'] + " | " + df_top10['LocationDesc']).str[:30]
    top10[(topic, question)] = df_top10

for (topic, question), df_top10 in top10.items():
    df_top10['Label'] = df_top10['Stratification1'] + " | " + df_top10['LocationDesc']
    year = df_top10['YearEnd'].iloc[0]
    metric = df_top10['DataValueType'].iloc[0]
    
    plt.figure(figsize=(12, 8))
    plt.bar(df_top10['Label'], df_top10['Difference'], color='blue')
    plt.xticks(rotation=45, ha='right')
    plt.ylabel('Difference')
    plt.title(f"{topic} / {question}\nTop 10 state-level differences between subgroup and overall population\nMetric: {metric}, Year: {year}")
    plt.tight_layout()
    plt.show()

# %%
cursor.close()
conn.close()
